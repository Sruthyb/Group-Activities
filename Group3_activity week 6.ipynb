# %% [markdown]
# # Q&A Activity Question Week - 06
#
# ## Read the data set into python.
#
# 1.Find out how many countries are there in the dataset.
#
# 2.Examine the data by using visualizations.
#
# 3.Find out how many countries with respect to the region are availablein the dataset.
#
# 4.On average which region has the highest.
#
#      a. GDP per capita (current US )
#
#      b. International trade: Imports (million US$)
#
# 5.Find out which region has more consistent with respect to GDP percapita (current US$)

# %%
import pandas as pd                       #importing packages
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# to read excel file in py environment
data= 'C:\SRUTHY B\Dataset_w6.xlsx'
df = pd.read_excel(data)
df
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   country                                     196 non-null    object
#  1   Region                                      196 non-null    object
#  2   Surface area (km2)                          196 non-null    int64
#  3   Population in thousands (2017)              196 non-null    int64
#  4   GDP per capita (current US$)                196 non-null    float64
#  5   Agricultural production index               196 non-null    int64
#  6   International trade: Imports (million US$)  196 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 10.8+ KB

# %% [markdown]
# there are no null values in the given dataset.

# %%
df.describe()
# Out:
#        Surface area (km2)  Population in thousands (2017)  \
# count        1.960000e+02                    1.960000e+02
# mean         6.787071e+05                    3.796658e+04
# std          1.914200e+06                    1.434228e+05
# min          2.600000e+01                    5.000000e+00
# 25%          2.084900e+04                    1.462000e+03
# 50%          1.136275e+05                    7.677500e+03
# 75%          5.077380e+05                    2.624075e+04
# max          1.709825e+07                    1.409517e+06
#
#        GDP per capita (current US$)  Agricultural production index   \
# count                    196.000000                      196.000000
# mean                   13727.343367                      117.066327
# std                    18995.593914                       25.521247
# min                      144.500000                       34.000000
# 25%                     1840.725000                      102.000000
# ...

# %% [markdown]
# ### 1. Find out how many countries are there in the dataset.

# %%
df['country'].nunique()
# Out:
# 196

# %% [markdown]
# Findings: Total no.of countries in the given dataset is found to be 196.

# %% [markdown]
# ### 2. Examine the data by using visualizations.

# %%
# using function regplot to make a scatterplot  ()
sns.set()
sns.regplot(x=df["Surface area (km2)"], y=df["Population in thousands (2017)"])
# Out:
# <AxesSubplot:xlabel='Surface area (km2)', ylabel='Population in thousands (2017)'>

# %% [markdown]
# Insights:
#
#      1. population density is concentrated in areas of lower surface area.
#
#      2. In areas of large surface area population is scattered.

# %%
# Plot the histogram  to the distplot function
sns.set()
sns.distplot( a=df["GDP per capita (current US$)"], hist=True, kde=False, rug=False,bins=10)
# Out:
# C:\Users\babu\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GDP per capita (current US$)'>

# %%
# plotting both distibutions on the same figure
sns.set()
fig = sns.kdeplot(df['Population in thousands (2017)'], shade=True, color="r")
fig = sns.kdeplot(df['GDP per capita (current US$)'], shade=True, color="b")
plt.show()

# %%
sns.set()
sns.jointplot(x=df["Population in thousands (2017)"], y=df["GDP per capita (current US$)"], kind='scatter')

# %% [markdown]
# Insights:
#
#  GDP is showing larger values for smaller populations. It is decreasing with increase in population.

# %%
sns.set(font_scale=2)
df['Region'].value_counts().plot(kind='bar',color='orange', figsize=(25,25))
plt.xlabel("Region",labelpad=14)
plt.ylabel("count of countries per region",labelpad=14)
plt.title("country");
plt.show()

# %% [markdown]
# Insights:
#
#     Most of the countries are from west asian region whereas from oceania have less countries.

# %%
sns.set()
sns.jointplot(x=df["GDP per capita (current US$)"], y=df["Region"],kind='scatter')

# %% [markdown]
# Insights:
#
#     Western european region have comparatively larger value GDP per capita than other regions.

# %% [markdown]
# ### 3. Find out how many countries with respect to the region are available in the dataset.

# %%
df.groupby(df['Region']).count().country
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %% [markdown]
# Findings:
#
#    The no. of countries from each region is given in the above table. Most countries are from western asian region and least from oceania region.

# %% [markdown]
# ### 4.  On average which region has the highest.
#
# ####      a. GDP per capita (current US$)
#
# ####    b. International trade: Imports (million US$)

# %%
# 4(a). sorting values by GDP per capita (current US$)
df[['Region','GDP per capita (current US$)']].groupby('Region').mean().sort_values('GDP per capita (current US$)',ascending=False).head()
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                  57659.000000
# WesternEurope                    55387.128571
# Oceania                          44823.250000
# NorthernEurope                   42098.220000
# EasternAsia                      27967.614286

# %% [markdown]
# Findings:
#
#     On average we can see north american region tops on GDP per capita compared to other regions.

# %%
# 4(b). Sorting values by International trade
df[['Region','International trade: Imports (million US$)']].groupby('Region').mean().sort_values('International trade: Imports (million US$)',ascending=False).head()
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                               663552.250000
# EasternAsia                                   451995.000000
# WesternEurope                                 407498.428571
# NorthernEurope                                113407.200000
# Oceania                                       112914.500000

# %% [markdown]
# Findings:
#
#     On International trade, again north american region tops the list.

# %% [markdown]
# ### 5.Find out which region has more consistent with respect to GDP percapita (current US$)

# %%
# method 1: by calculating mode
df[['Region','GDP per capita (current US$)']].mode()
# Out:
#         Region  GDP per capita (current US$)
# 0  WesternAsia                        1106.4

# %%
# method 2: By Coefficient of variation
df_new = df.groupby('Region')['GDP per capita (current US$)'].describe()
df_new['CV'] = (df_new['std']/df_new['mean'])*100
df_new.sort_values(by='CV',ascending=True).head()
# Out:
#                  count          mean           std      min        25%  \
# Region
# Oceania            2.0  44823.250000   9233.329638  38294.3  41558.775
# NorthernAfrica     5.0   3934.960000    974.706575   2919.3   3452.300
# NorthernAmerica    4.0  57659.000000  25749.619445  36976.7  41648.375
# WesternEurope      7.0  55387.128571  24770.467728  36304.2  40982.000
# NorthernEurope    10.0  42098.220000  20671.030185  13704.1  23371.025
#
#                       50%        75%       max         CV
# Region
# Oceania          44823.25  48087.725   51352.2  20.599420
# NorthernAfrica    3660.90   4154.100    5488.2  24.770432
# NorthernAmerica  49629.70  65640.325   94399.9  44.658457
# WesternEurope    44117.70  62581.600  100160.8  44.722426
# NorthernEurope   47424.95  52595.975   74185.5  49.101910

# %% [markdown]
# Findings:
#
#   1) from method 1, The west asian region is more consistent with w.r.t GDP per capita.
#   2) from method 2, oceania region have lower coeficient of variation w.r.t GDP per capita.
